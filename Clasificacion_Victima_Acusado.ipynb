# %% [markdown]
# # Clasificacion victima y acusado:
# ***
# ***

# %% [markdown]
# ### Importar libreras, Lectura y asignacion de Variable

# %%
# Importa Librerias
import pandas as pd
import re

# %%
# Se carga el Excel en DataFrame y se visiualiza
clas_victima_acusado = pd.read_excel('Data/tipo_usuario_via.xlsx')

# %% [markdown]
# ***
# ### Configuracion Visual observar completos los DataFrame

# %%
# Seteo para ver completamenta las columnas y las filas
pd.set_option('display.max_columns', None)
pd.set_option('display.max_rows', None)

# %% [markdown]
# ***
# ### - Informacion general y visualizacion del DataFrame

# %%
clas_victima_acusado.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 28 entries, 0 to 27
# Data columns (total 6 columns):
#  #   Column                   Non-Null Count  Dtype
# ---  ------                   --------------  -----
#  0   Original_victima         17 non-null     object
#  1   LESIONES                 17 non-null     object
#  2   FATALES INFORME ANUAL    17 non-null     object
#  3   Original_acusado         28 non-null     object
#  4   LESIONES.1               28 non-null     object
#  5   FATALES INFORME ANUAL.1  28 non-null     object
# dtypes: object(6)
# memory usage: 1.4+ KB

# %%
# Visualizar los 5 primeros registros
clas_victima_acusado.head(100)
# Out:
#                                      Original_victima            LESIONES  \
# 0                                              PEATON              PEATON
# 1                                             PEATON               PEATON
# 2                                                MOTO                MOTO
# 3                                                AUTO                AUTO
# 4                                     AUTO PARTICULAR                AUTO
# 5                                                TAXI                TAXI
# 6                                          TAXI/REMIS                TAXI
# 7                                              CAMION              CAMION
# 8                         TRANSPORTE DE CARGAS / GRUA              CAMION
# 9                                          UTILITARIO           CAMIONETA
# 10                                          BICICLETA           BICICLETA
# 11                            TRANSPORTE DE PASAJEROS  TRANSPORTE PUBLICO
# ...

# %% [markdown]
# ***
# ### Registros duplicados:

# %%
# Controla los duplicados
clas_victima_acusado = clas_victima_acusado.duplicated()
print(f'Cantidad de registros duplicados: {clas_victima_acusado.sum()}')
# Out:
# Cantidad de registros duplicados: 0

# %% [markdown]
# ***
